# %% [markdown]
# # PANDAS V: EJERCICIOS

# %% [markdown]
# Estos ejercicios te permitirán repasar y consolidar lo que has aprendido en el módulo de Pandas V.
#
# No hagas los ejercicios hasta que hayas estudiado el contenido de su notebook.
#
# Instrucciones:
#
# * Crea una copia de este notebook antes de escribir nada. De esa forma respetarás el original para volver a hacerlo
# * Cada ejercicio tiene unas instrucciones de lo que debes hacer en él
# * Bajo las instrucciones estará una celda vacía, aquí es donde tú debes escribir la solución
# * Y bajo esta última celda verás que hay otras dos celdas. La primera está vacía y no la debes tocar. Es para que tengas siempre a mano la solución al ejercicio, ya que esta no va a cambiar

# %%
#Te dejo creada la importación de los paquetes
import pandas as pd

# %% [markdown]
# En esta práctica vamos a continuar con el dataset que contiene los accidentes de tráfico en Madrid durante 2020.
#
# Recuerda que está en Excel, se llama 00_Datasets/2020_Accidentalidad.xlsx y está en la carpeta 00_Datasets.
#
# En la anterior práctica habíamos identificado entre otros los siguientes problemas de calidad de datos:
#
# * El índice debería ser el número de expediente
# * Nos importaba casi todas las variables como objeto
# * Las 2 últimas variables no contienen información
# * Había registros duplicados
# * Teníamos muchos nulos
#
# En esta práctica vamos a ir corrigéndolos uno a uno.
#
# En cada paso acuérdate de guardar los cambios en df para que los vaya acumulando.

# %% [markdown]
# ## Ejercicio:
#
# Importa el archivo en el objeto df y visualizalo por pantalla.

# %%
df = pd.read_excel('../../00_Datasets/2020_Accidentalidad.xlsx')
df
# Out:
#       Nº  EXPEDIENTE      FECHA      HORA  \
# 0        2020S000057 2020-01-01  23:15:00
# 1        2020S000038 2020-01-01  22:35:00
# 2        2020S000060 2020-01-01  20:15:00
# 3        2020S000060 2020-01-01  20:15:00
# 4        2020S000033 2020-01-01  19:45:00
# ...              ...        ...       ...
# 28768    2020S017541 2020-11-30  08:02:00
# 28769    2020S017541 2020-11-30  08:02:00
# 28770    2020S017328 2020-11-30  00:30:00
# 28771    2020S017328 2020-11-30  00:30:00
# 28772    2020S017328 2020-11-30  00:30:00
#
#                                                    CALLE NÚMERO  \
# 0      AVDA. CIUDAD DE BARCELONA / CALL. DOCTOR ESQUERDO      -
# 1      CALL. VALLE DE TORANZO / CALL. SIERRA DE PAJAREJO      -
# 2                           GTA. MARIANO SALVADOR MAELLA      1
# 3                           GTA. MARIANO SALVADOR MAELLA      1
# 4                                           CALL. OLIVAR     40
# ...                                                  ...    ...
# ...

# %%
#No tocar, es para que veas la solución
# Out:
#       Nº  EXPEDIENTE      FECHA      HORA  \
# 0        2020S000057 2020-01-01  23:15:00
# 1        2020S000038 2020-01-01  22:35:00
# 2        2020S000060 2020-01-01  20:15:00
# 3        2020S000060 2020-01-01  20:15:00
# 4        2020S000033 2020-01-01  19:45:00
# ...              ...        ...       ...
# 28768    2020S017541 2020-11-30  08:02:00
# 28769    2020S017541 2020-11-30  08:02:00
# 28770    2020S017328 2020-11-30  00:30:00
# 28771    2020S017328 2020-11-30  00:30:00
# 28772    2020S017328 2020-11-30  00:30:00
#
#                                                    CALLE NÚMERO  \
# 0      AVDA. CIUDAD DE BARCELONA / CALL. DOCTOR ESQUERDO      -
# 1      CALL. VALLE DE TORANZO / CALL. SIERRA DE PAJAREJO      -
# 2                           GTA. MARIANO SALVADOR MAELLA      1
# 3                           GTA. MARIANO SALVADOR MAELLA      1
# 4                                           CALL. OLIVAR     40
# ...                                                  ...    ...
# ...

# %% [markdown]
# ## Ejercicio:
#
# Establece Nº EXPEDIENTE como el index y visualiza df por pantalla

# %%
df.set_index('Nº  EXPEDIENTE', inplace=True)
df
# Out:
#                     FECHA      HORA  \
# Nº  EXPEDIENTE
# 2020S000057    2020-01-01  23:15:00
# 2020S000038    2020-01-01  22:35:00
# 2020S000060    2020-01-01  20:15:00
# 2020S000060    2020-01-01  20:15:00
# 2020S000033    2020-01-01  19:45:00
# ...                   ...       ...
# 2020S017541    2020-11-30  08:02:00
# 2020S017541    2020-11-30  08:02:00
# 2020S017328    2020-11-30  00:30:00
# 2020S017328    2020-11-30  00:30:00
# 2020S017328    2020-11-30  00:30:00
#
#                                                             CALLE NÚMERO  \
# Nº  EXPEDIENTE
# 2020S000057     AVDA. CIUDAD DE BARCELONA / CALL. DOCTOR ESQUERDO      -
# 2020S000038     CALL. VALLE DE TORANZO / CALL. SIERRA DE PAJAREJO      -
# 2020S000060                          GTA. MARIANO SALVADOR MAELLA      1
# 2020S000060                          GTA. MARIANO SALVADOR MAELLA      1
# 2020S000033                                          CALL. OLIVAR     40
# ...

# %%
#No tocar, es para que veas la solución
# Out:
#                     FECHA      HORA  \
# Nº  EXPEDIENTE
# 2020S000057    2020-01-01  23:15:00
# 2020S000038    2020-01-01  22:35:00
# 2020S000060    2020-01-01  20:15:00
# 2020S000060    2020-01-01  20:15:00
# 2020S000033    2020-01-01  19:45:00
# ...                   ...       ...
# 2020S017541    2020-11-30  08:02:00
# 2020S017541    2020-11-30  08:02:00
# 2020S017328    2020-11-30  00:30:00
# 2020S017328    2020-11-30  00:30:00
# 2020S017328    2020-11-30  00:30:00
#
#                                                             CALLE NÚMERO  \
# Nº  EXPEDIENTE
# 2020S000057     AVDA. CIUDAD DE BARCELONA / CALL. DOCTOR ESQUERDO      -
# 2020S000038     CALL. VALLE DE TORANZO / CALL. SIERRA DE PAJAREJO      -
# 2020S000060                          GTA. MARIANO SALVADOR MAELLA      1
# 2020S000060                          GTA. MARIANO SALVADOR MAELLA      1
# 2020S000033                                          CALL. OLIVAR     40
# ...

# %% [markdown]
# ## Ejercicio:
#
# Elimina las 2 últimas variables.

# %%
df.drop(columns=['Unnamed: 14', 'Unnamed: 13'], inplace=True)
df
# Out:
#                     FECHA      HORA  \
# Nº  EXPEDIENTE
# 2020S000057    2020-01-01  23:15:00
# 2020S000038    2020-01-01  22:35:00
# 2020S000060    2020-01-01  20:15:00
# 2020S000060    2020-01-01  20:15:00
# 2020S000033    2020-01-01  19:45:00
# ...                   ...       ...
# 2020S017541    2020-11-30  08:02:00
# 2020S017541    2020-11-30  08:02:00
# 2020S017328    2020-11-30  00:30:00
# 2020S017328    2020-11-30  00:30:00
# 2020S017328    2020-11-30  00:30:00
#
#                                                             CALLE NÚMERO  \
# Nº  EXPEDIENTE
# 2020S000057     AVDA. CIUDAD DE BARCELONA / CALL. DOCTOR ESQUERDO      -
# 2020S000038     CALL. VALLE DE TORANZO / CALL. SIERRA DE PAJAREJO      -
# 2020S000060                          GTA. MARIANO SALVADOR MAELLA      1
# 2020S000060                          GTA. MARIANO SALVADOR MAELLA      1
# 2020S000033                                          CALL. OLIVAR     40
# ...

# %%
#No tocar, es para que veas la solución
# Out:
#                     FECHA      HORA  \
# Nº  EXPEDIENTE
# 2020S000057    2020-01-01  23:15:00
# 2020S000038    2020-01-01  22:35:00
# 2020S000060    2020-01-01  20:15:00
# 2020S000060    2020-01-01  20:15:00
# 2020S000033    2020-01-01  19:45:00
# ...                   ...       ...
# 2020S017541    2020-11-30  08:02:00
# 2020S017541    2020-11-30  08:02:00
# 2020S017328    2020-11-30  00:30:00
# 2020S017328    2020-11-30  00:30:00
# 2020S017328    2020-11-30  00:30:00
#
#                                                             CALLE NÚMERO  \
# Nº  EXPEDIENTE
# 2020S000057     AVDA. CIUDAD DE BARCELONA / CALL. DOCTOR ESQUERDO      -
# 2020S000038     CALL. VALLE DE TORANZO / CALL. SIERRA DE PAJAREJO      -
# 2020S000060                          GTA. MARIANO SALVADOR MAELLA      1
# 2020S000060                          GTA. MARIANO SALVADOR MAELLA      1
# 2020S000033                                          CALL. OLIVAR     40
# ...

# %% [markdown]
# ## Ejercicio:
#
# Elimina el '*' de la variable LESIVIDAD

# %%
df.rename(columns= {'LESIVIDAD*': 'LESIVIDAD'}, inplace=True)
df
# Out:
#                     FECHA      HORA  \
# Nº  EXPEDIENTE
# 2020S000057    2020-01-01  23:15:00
# 2020S000038    2020-01-01  22:35:00
# 2020S000060    2020-01-01  20:15:00
# 2020S000060    2020-01-01  20:15:00
# 2020S000033    2020-01-01  19:45:00
# ...                   ...       ...
# 2020S017541    2020-11-30  08:02:00
# 2020S017541    2020-11-30  08:02:00
# 2020S017328    2020-11-30  00:30:00
# 2020S017328    2020-11-30  00:30:00
# 2020S017328    2020-11-30  00:30:00
#
#                                                             CALLE NÚMERO  \
# Nº  EXPEDIENTE
# 2020S000057     AVDA. CIUDAD DE BARCELONA / CALL. DOCTOR ESQUERDO      -
# 2020S000038     CALL. VALLE DE TORANZO / CALL. SIERRA DE PAJAREJO      -
# 2020S000060                          GTA. MARIANO SALVADOR MAELLA      1
# 2020S000060                          GTA. MARIANO SALVADOR MAELLA      1
# 2020S000033                                          CALL. OLIVAR     40
# ...

# %%
#No tocar, es para que veas la solución
# Out:
#                     FECHA      HORA  \
# Nº  EXPEDIENTE
# 2020S000057    2020-01-01  23:15:00
# 2020S000038    2020-01-01  22:35:00
# 2020S000060    2020-01-01  20:15:00
# 2020S000060    2020-01-01  20:15:00
# 2020S000033    2020-01-01  19:45:00
# ...                   ...       ...
# 2020S017541    2020-11-30  08:02:00
# 2020S017541    2020-11-30  08:02:00
# 2020S017328    2020-11-30  00:30:00
# 2020S017328    2020-11-30  00:30:00
# 2020S017328    2020-11-30  00:30:00
#
#                                                             CALLE NÚMERO  \
# Nº  EXPEDIENTE
# 2020S000057     AVDA. CIUDAD DE BARCELONA / CALL. DOCTOR ESQUERDO      -
# 2020S000038     CALL. VALLE DE TORANZO / CALL. SIERRA DE PAJAREJO      -
# 2020S000060                          GTA. MARIANO SALVADOR MAELLA      1
# 2020S000060                          GTA. MARIANO SALVADOR MAELLA      1
# 2020S000033                                          CALL. OLIVAR     40
# ...

# %% [markdown]
# ## Ejercicio:
#
# Elimina los registros duplicados.

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                     FECHA      HORA  \
# Nº  EXPEDIENTE
# 2020S000057    2020-01-01  23:15:00
# 2020S000038    2020-01-01  22:35:00
# 2020S000060    2020-01-01  20:15:00
# 2020S000060    2020-01-01  20:15:00
# 2020S000033    2020-01-01  19:45:00
# ...                   ...       ...
# 2020S017541    2020-11-30  08:02:00
# 2020S017541    2020-11-30  08:02:00
# 2020S017328    2020-11-30  00:30:00
# 2020S017328    2020-11-30  00:30:00
# 2020S017328    2020-11-30  00:30:00
#
#                                                             CALLE NÚMERO  \
# Nº  EXPEDIENTE
# 2020S000057     AVDA. CIUDAD DE BARCELONA / CALL. DOCTOR ESQUERDO      -
# 2020S000038     CALL. VALLE DE TORANZO / CALL. SIERRA DE PAJAREJO      -
# 2020S000060                          GTA. MARIANO SALVADOR MAELLA      1
# 2020S000060                          GTA. MARIANO SALVADOR MAELLA      1
# 2020S000033                                          CALL. OLIVAR     40
# ...

# %%
#No tocar, es para que veas la solución
# Out:
#                     FECHA      HORA  \
# Nº  EXPEDIENTE
# 2020S000057    2020-01-01  23:15:00
# 2020S000038    2020-01-01  22:35:00
# 2020S000060    2020-01-01  20:15:00
# 2020S000060    2020-01-01  20:15:00
# 2020S000033    2020-01-01  19:45:00
# ...                   ...       ...
# 2020S017541    2020-11-30  08:02:00
# 2020S017541    2020-11-30  08:02:00
# 2020S017328    2020-11-30  00:30:00
# 2020S017328    2020-11-30  00:30:00
# 2020S017328    2020-11-30  00:30:00
#
#                                                             CALLE NÚMERO  \
# Nº  EXPEDIENTE
# 2020S000057     AVDA. CIUDAD DE BARCELONA / CALL. DOCTOR ESQUERDO      -
# 2020S000038     CALL. VALLE DE TORANZO / CALL. SIERRA DE PAJAREJO      -
# 2020S000060                          GTA. MARIANO SALVADOR MAELLA      1
# 2020S000060                          GTA. MARIANO SALVADOR MAELLA      1
# 2020S000033                                          CALL. OLIVAR     40
# ...

# %% [markdown]
# ## Ejercicio:
#
# Corrige los tipos de las variables.
#
# Pista: desde distrito a sexo ambos incluídos deberían ser categóricas. El resto puedes dejarlo como está.

# %%
df.dtypes
# Out:
# FECHA                   datetime64[ns]
# HORA                            object
# CALLE                           object
# NÚMERO                          object
# DISTRITO                        object
# TIPO ACCIDENTE                  object
# ESTADO METEREOLÓGICO            object
# TIPO VEHÍCULO                   object
# TIPO PERSONA                    object
# RANGO DE EDAD                   object
# SEXO                            object
# LESIVIDAD                      float64
# dtype: object

# %%
#Revisamos los tipos

#No tocar, es para que veas la solución
# Out:
# FECHA                   datetime64[ns]
# HORA                            object
# CALLE                           object
# NÚMERO                          object
# DISTRITO                        object
# TIPO ACCIDENTE                  object
# ESTADO METEREOLÓGICO            object
# TIPO VEHÍCULO                   object
# TIPO PERSONA                    object
# RANGO DE EDAD                   object
# SEXO                            object
# LESIVIDAD                      float64
# dtype: object

# %% [markdown]
# Cambia los tipos de las variables indicadas.

# %%
df[df.loc[ : , 'DISTRITO' : 'SEXO'].columns ] = df.loc[ : , 'DISTRITO' : 'SEXO'].astype('category')
df.dtypes
# Out:
# FECHA                   datetime64[ns]
# HORA                            object
# CALLE                           object
# NÚMERO                          object
# DISTRITO                      category
# TIPO ACCIDENTE                category
# ESTADO METEREOLÓGICO          category
# TIPO VEHÍCULO                 category
# TIPO PERSONA                  category
# RANGO DE EDAD                 category
# SEXO                          category
# LESIVIDAD                      float64
# dtype: object

# %%
#Volvermos a revisar los tipos

#No tocar, es para que veas la solución
# Out:
# FECHA                   datetime64[ns]
# HORA                            object
# CALLE                           object
# NÚMERO                          object
# DISTRITO                      category
# TIPO ACCIDENTE                category
# ESTADO METEREOLÓGICO          category
# TIPO VEHÍCULO                 category
# TIPO PERSONA                  category
# RANGO DE EDAD                 category
# SEXO                          category
# LESIVIDAD                      float64
# dtype: object

# %% [markdown]
# ## Ejercicio:
#
# Gestiona los nulos.
#
# Con el tema nulos hay que variable a variable tomando una decisión.
#
# Así que antes que nada vuelve a sacar el conteo de nulos por variable.

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# LESIVIDAD               11943
# ESTADO METEREOLÓGICO     2570
# SEXO                     2454
# TIPO VEHÍCULO             137
# TIPO ACCIDENTE             31
# TIPO PERSONA               25
# DISTRITO                    2
# NÚMERO                      2
# CALLE                       0
# HORA                        0
# FECHA                       0
# RANGO DE EDAD               0
# dtype: int64

# %%
#No tocar, es para que veas la solución
# Out:
# LESIVIDAD               11943
# ESTADO METEREOLÓGICO     2570
# SEXO                     2454
# TIPO VEHÍCULO             137
# TIPO ACCIDENTE             31
# TIPO PERSONA               25
# NÚMERO                      2
# DISTRITO                    2
# FECHA                       0
# HORA                        0
# CALLE                       0
# RANGO DE EDAD               0
# dtype: int64

# %% [markdown]
# Analizando la naturaleza y el conteo de cada variable podríamos llegar las siguientes conclusiones:
#
# * En NÚMERO y DISTRITO son solo 2 nulos: eliminar nulos
# * TIPO PERSONA, TIPO ACCIDENTE Y TIPO VEHÍCULO tienen pocos nulos y podemos imputarlos por la moda
# * En el SEXO y ESTADO METEREOLÓGICO vamos a crear una categoría "Se desconoce"
# * En LESIVIDAD, a diferencia de las anteriores podría ser que no hubo lesión en ese accidente, así que sustituiremos por cero
#
# Acuérdate de ir guardando en df en cada paso.

# %% [markdown]
# ## Ejercicio:
#
# Elimina los registros que tienen nulo en numero o distrito

# %%
#No tocar, es para que veas la solución
# Out:
#                     FECHA      HORA  \
# Nº  EXPEDIENTE
# 2020S000057    2020-01-01  23:15:00
# 2020S000038    2020-01-01  22:35:00
# 2020S000060    2020-01-01  20:15:00
# 2020S000060    2020-01-01  20:15:00
# 2020S000033    2020-01-01  19:45:00
# ...                   ...       ...
# 2020S017541    2020-11-30  08:02:00
# 2020S017541    2020-11-30  08:02:00
# 2020S017328    2020-11-30  00:30:00
# 2020S017328    2020-11-30  00:30:00
# 2020S017328    2020-11-30  00:30:00
#
#                                                             CALLE NÚMERO  \
# Nº  EXPEDIENTE
# 2020S000057     AVDA. CIUDAD DE BARCELONA / CALL. DOCTOR ESQUERDO      -
# 2020S000038     CALL. VALLE DE TORANZO / CALL. SIERRA DE PAJAREJO      -
# 2020S000060                          GTA. MARIANO SALVADOR MAELLA      1
# 2020S000060                          GTA. MARIANO SALVADOR MAELLA      1
# 2020S000033                                          CALL. OLIVAR     40
# ...

# %% [markdown]
# ## Ejercicio:
#
# Imputa por la moda en TIPO PERSONA, TIPO ACCIDENTE Y TIPO VEHÍCULO.

# %%
#No tocar, es para que veas la solución
# Out:
# 'Conductor'

# %% [markdown]
# Haz las imputaciones

# %%
#No tocar, es para que veas la solución
# Out:
# TIPO PERSONA
# Conductor    22427
# Pasajero      4033
# Peatón         996
# Name: count, dtype: int64

# %% [markdown]
# ## Ejercicio:
#
# En el SEXO y ESTADO METEREOLÓGICO reemplaza los nulos por 'Se desconoce'

# %% [markdown]
# Revisa si los niveles actuales de ambas varables incluyen la categoría 'Se desconoce'

# %%
#No tocar, es para que veas la solución
# Out:
# Index(['Hombre', 'Mujer'], dtype='object')

# %%
#No tocar, es para que veas la solución
# Out:
# Index(['Despejado', 'Granizando', 'LLuvia intensa', 'Lluvia débil', 'Nevando',
#        'Nublado', 'Se desconoce'],
#       dtype='object')

# %% [markdown]
# Reemplaza los nulos, pero recuerda que primero debes añadir la nueva categoria.

# %%
#Primero añadimos las categorías donde no existan


#Y después reemplazamos los nulos

# %% [markdown]
# Haz un conteo de cada variable para comprobar que se ha añadido correctamente.

# %%
#Comprobamos que se ha añadido

#No tocar, es para que veas la solución
# Out:
# SEXO
# Hombre          17170
# Mujer            7832
# Se desconoce     2454
# Name: count, dtype: int64

# %%
#Comprobamos que se ha añadido

#No tocar, es para que veas la solución
# Out:
# ESTADO METEREOLÓGICO
# Despejado         21197
# Se desconoce       2943
# Lluvia débil       1573
# Nublado            1447
# LLuvia intensa      285
# Granizando            9
# Nevando               2
# Name: count, dtype: int64

# %% [markdown]
# ## Ejercicio:
#
# En LESIVIDAD sustituye los nulos por un cero.

# %%
#No tocar, es para que veas la solución
# Out:
#                     FECHA      HORA  \
# Nº  EXPEDIENTE
# 2020S000057    2020-01-01  23:15:00
# 2020S000038    2020-01-01  22:35:00
# 2020S000060    2020-01-01  20:15:00
# 2020S000060    2020-01-01  20:15:00
# 2020S000033    2020-01-01  19:45:00
# ...                   ...       ...
# 2020S017541    2020-11-30  08:02:00
# 2020S017541    2020-11-30  08:02:00
# 2020S017328    2020-11-30  00:30:00
# 2020S017328    2020-11-30  00:30:00
# 2020S017328    2020-11-30  00:30:00
#
#                                                             CALLE NÚMERO  \
# Nº  EXPEDIENTE
# 2020S000057     AVDA. CIUDAD DE BARCELONA / CALL. DOCTOR ESQUERDO      -
# 2020S000038     CALL. VALLE DE TORANZO / CALL. SIERRA DE PAJAREJO      -
# 2020S000060                          GTA. MARIANO SALVADOR MAELLA      1
# 2020S000060                          GTA. MARIANO SALVADOR MAELLA      1
# 2020S000033                                          CALL. OLIVAR     40
# ...

# %% [markdown]
# ## Ejercicio:
#
# Vuelve a sacar el conteo de nulos para ver si está todo bien.

# %%
#No tocar, es para que veas la solución
# Out:
# FECHA                   0
# HORA                    0
# CALLE                   0
# NÚMERO                  0
# DISTRITO                0
# TIPO ACCIDENTE          0
# ESTADO METEREOLÓGICO    0
# TIPO VEHÍCULO           0
# TIPO PERSONA            0
# RANGO DE EDAD           0
# SEXO                    0
# LESIVIDAD               0
# dtype: int64

# %% [markdown]
# BUEN TRABAJO!!!
