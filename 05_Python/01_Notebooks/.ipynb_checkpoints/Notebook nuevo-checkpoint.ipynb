# %% [markdown]
# # ESTE ES UN TÍTULO

# %% [markdown]
# ## ESTE ES UN SUBTÍTULO

# %% [markdown]
# ### SECCIÓN 1

# %% [markdown]
# Este es el *análisis* de los mercados **bursátiles**
#
# Los indicadores son:
#
# 1. Indicador 1
# 2. Indicador 2
# 3. Indicador 3

# %% [markdown]
# ### SECCIÓN 2

# %% [markdown]
# ![image.png](attachment:0a2c450a-fd23-4ee6-9f4c-554e83d0934c.png)

# %% [markdown]
# [DS4B](https://www.datascience4business.com)

# %% [markdown]
# (https://www.datascience4business.com)
