# %% [markdown]
# # PANDAS IV: EJERCICIOS

# %% [markdown]
# Estos ejercicios te permitirán repasar y consolidar lo que has aprendido en el módulo de Pandas IV.
#
# No hagas los ejercicios hasta que hayas estudiado el contenido de su notebook.
#
# Instrucciones:
#
# * Crea una copia de este notebook antes de escribir nada. De esa forma respetarás el original para volver a hacerlo
# * Cada ejercicio tiene unas instrucciones de lo que debes hacer en él
# * Bajo las instrucciones estará una celda vacía, aquí es donde tú debes escribir la solución
# * Y bajo esta última celda verás que hay otras dos celdas. La primera está vacía y no la debes tocar. Es para que tengas siempre a mano la solución al ejercicio, ya que esta no va a cambiar

# %%
#Te dejo creada la importación de los paquetes
import pandas as pd

# %% [markdown]
# Esta práctica consiste en analizar la calidad de datos de un dataset que contiene los accidentes de tráfico en Madrid durante 2020.
#
# Está en Excel, se llama 2020_Accidentalidad.xlsx.
#
# En una situación real irías apuntando todo lo que te pareciera extraño o erróneo de los resultados de estos análisis para correjirlo después con las técnicas que aprenderemos en el siguiente módulo.

# %% [markdown]
# ## Ejercicio:
#
# Importa el archivo en el objeto df y visualizalo por pantalla.

# %%
df = pd.read_excel('../../00_Datasets/2020_Accidentalidad.xlsx')
df.head()
# Out:
#   Nº  EXPEDIENTE      FECHA      HORA  \
# 0    2020S000057 2020-01-01  23:15:00
# 1    2020S000038 2020-01-01  22:35:00
# 2    2020S000060 2020-01-01  20:15:00
# 3    2020S000060 2020-01-01  20:15:00
# 4    2020S000033 2020-01-01  19:45:00
#
#                                                CALLE NÚMERO  \
# 0  AVDA. CIUDAD DE BARCELONA / CALL. DOCTOR ESQUERDO      -
# 1  CALL. VALLE DE TORANZO / CALL. SIERRA DE PAJAREJO      -
# 2                       GTA. MARIANO SALVADOR MAELLA      1
# 3                       GTA. MARIANO SALVADOR MAELLA      1
# 4                                       CALL. OLIVAR     40
#
#               DISTRITO                TIPO ACCIDENTE ESTADO METEREOLÓGICO  \
# 0               RETIRO  Choque contra obstáculo fijo            Despejado
# 1      MONCLOA-ARAVACA                         Caída            Despejado
# 2  FUENCARRAL-EL PARDO                         Caída            Despejado
# ...

# %%
#No tocar, es para que veas la solución
# Out:
#       Nº  EXPEDIENTE      FECHA      HORA  \
# 0        2020S000057 2020-01-01  23:15:00
# 1        2020S000038 2020-01-01  22:35:00
# 2        2020S000060 2020-01-01  20:15:00
# ...              ...        ...       ...
# 28770    2020S017328 2020-11-30  00:30:00
# 28771    2020S017328 2020-11-30  00:30:00
# 28772    2020S017328 2020-11-30  00:30:00
#
#                                                    CALLE NÚMERO  \
# 0      AVDA. CIUDAD DE BARCELONA / CALL. DOCTOR ESQUERDO      -
# 1      CALL. VALLE DE TORANZO / CALL. SIERRA DE PAJAREJO      -
# 2                           GTA. MARIANO SALVADOR MAELLA      1
# ...                                                  ...    ...
# 28770                                CALL. MARCELO USERA     36
# 28771                                CALL. MARCELO USERA     36
# 28772                                CALL. MARCELO USERA     36
#
#                   DISTRITO                TIPO ACCIDENTE ESTADO METEREOLÓGICO  \
# ...

# %% [markdown]
# ## Ejercicio:
#
# ¿Cuanto espacio en memoria está ocupando este dataset?

# %%
df.info(memory_usage= 'deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28773 entries, 0 to 28772
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Nº  EXPEDIENTE        28773 non-null  object
#  1   FECHA                 28773 non-null  datetime64[ns]
#  2   HORA                  28773 non-null  object
#  3   CALLE                 28773 non-null  object
#  4   NÚMERO                28771 non-null  object
#  5   DISTRITO              28771 non-null  object
#  6   TIPO ACCIDENTE        28740 non-null  object
#  7   ESTADO METEREOLÓGICO  25964 non-null  object
#  8   TIPO VEHÍCULO         28633 non-null  object
#  9   TIPO PERSONA          28746 non-null  object
#  10  RANGO DE EDAD         28773 non-null  object
#  11  SEXO                  25398 non-null  object
#  12  LESIVIDAD*            15718 non-null  float64
#  13  Unnamed: 13           0 non-null      float64
# ...

# %%
#No tocar, es para que veas la solución
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28773 entries, 0 to 28772
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Nº  EXPEDIENTE        28773 non-null  object
#  1   FECHA                 28773 non-null  datetime64[ns]
#  2   HORA                  28773 non-null  object
#  3   CALLE                 28773 non-null  object
#  4   NÚMERO                28771 non-null  object
#  5   DISTRITO              28771 non-null  object
#  6   TIPO ACCIDENTE        28740 non-null  object
#  7   ESTADO METEREOLÓGICO  25964 non-null  object
#  8   TIPO VEHÍCULO         28633 non-null  object
#  9   TIPO PERSONA          28746 non-null  object
#  10  RANGO DE EDAD         28773 non-null  object
#  11  SEXO                  25398 non-null  object
#  12  LESIVIDAD*            15718 non-null  float64
#  13  Unnamed: 13           0 non-null      float64
# ...

# %% [markdown]
# BUEN TRABAJO!!!

# %% [markdown]
# ## Ejercicio:
#
# ¿Cuantas filas y columnas tiene?

# %%
df.shape
# Out:
# (28773, 15)

# %%
#No tocar, es para que veas la solución
# Out:
# (28773, 15)

# %% [markdown]
# ## Ejercicio:
#
# ¿Tiene índice ya asignado?¿O es el automático?

# %%
df.index
# Out:
# RangeIndex(start=0, stop=28773, step=1)

# %%
#No tocar, es para que veas la solución
# Out:
# RangeIndex(start=0, stop=28773, step=1)

# %% [markdown]
# ## Ejercicio:
#
# Asigna 'Nº  EXPEDIENTE' columna como el índice.

# %%
df.set_index('Nº  EXPEDIENTE', inplace=True)
df
# Out:
#                     FECHA      HORA  \
# Nº  EXPEDIENTE
# 2020S000057    2020-01-01  23:15:00
# 2020S000038    2020-01-01  22:35:00
# 2020S000060    2020-01-01  20:15:00
# 2020S000060    2020-01-01  20:15:00
# 2020S000033    2020-01-01  19:45:00
# ...                   ...       ...
# 2020S017541    2020-11-30  08:02:00
# 2020S017541    2020-11-30  08:02:00
# 2020S017328    2020-11-30  00:30:00
# 2020S017328    2020-11-30  00:30:00
# 2020S017328    2020-11-30  00:30:00
#
#                                                             CALLE NÚMERO  \
# Nº  EXPEDIENTE
# 2020S000057     AVDA. CIUDAD DE BARCELONA / CALL. DOCTOR ESQUERDO      -
# 2020S000038     CALL. VALLE DE TORANZO / CALL. SIERRA DE PAJAREJO      -
# 2020S000060                          GTA. MARIANO SALVADOR MAELLA      1
# 2020S000060                          GTA. MARIANO SALVADOR MAELLA      1
# 2020S000033                                          CALL. OLIVAR     40
# ...

# %%
#No tocar, es para que veas la solución
# Out:
#                     FECHA      HORA  \
# Nº  EXPEDIENTE
# 2020S000057    2020-01-01  23:15:00
# 2020S000038    2020-01-01  22:35:00
# 2020S000060    2020-01-01  20:15:00
# 2020S000060    2020-01-01  20:15:00
# 2020S000033    2020-01-01  19:45:00
# ...                   ...       ...
# 2020S017541    2020-11-30  08:02:00
# 2020S017541    2020-11-30  08:02:00
# 2020S017328    2020-11-30  00:30:00
# 2020S017328    2020-11-30  00:30:00
# 2020S017328    2020-11-30  00:30:00
#
#                                                             CALLE NÚMERO  \
# Nº  EXPEDIENTE
# 2020S000057     AVDA. CIUDAD DE BARCELONA / CALL. DOCTOR ESQUERDO      -
# 2020S000038     CALL. VALLE DE TORANZO / CALL. SIERRA DE PAJAREJO      -
# 2020S000060                          GTA. MARIANO SALVADOR MAELLA      1
# 2020S000060                          GTA. MARIANO SALVADOR MAELLA      1
# 2020S000033                                          CALL. OLIVAR     40
# ...

# %% [markdown]
# ## Ejercicio:
#
# Extrae los nombres de las variables como una lista

# %%
df.columns.to_list()
# Out:
# ['FECHA',
#  'HORA',
#  'CALLE',
#  'NÚMERO',
#  'DISTRITO',
#  'TIPO ACCIDENTE',
#  'ESTADO METEREOLÓGICO',
#  'TIPO VEHÍCULO',
#  'TIPO PERSONA',
#  'RANGO DE EDAD',
#  'SEXO',
#  'LESIVIDAD*',
#  'Unnamed: 13',
#  'Unnamed: 14']

# %%
#No tocar, es para que veas la solución
# Out:
# ['FECHA',
#  'HORA',
#  'CALLE',
#  'NÚMERO',
#  'DISTRITO',
#  'TIPO ACCIDENTE',
#  'ESTADO METEREOLÓGICO',
#  'TIPO VEHÍCULO',
#  'TIPO PERSONA',
#  'RANGO DE EDAD',
#  'SEXO',
#  'LESIVIDAD*',
#  'Unnamed: 13',
#  'Unnamed: 14']

# %% [markdown]
# ## Ejercicio:
#
# Comprueba los tipos de las variables

# %%
df.dtypes
# Out:
# FECHA                   datetime64[ns]
# HORA                            object
# CALLE                           object
# NÚMERO                          object
# DISTRITO                        object
# TIPO ACCIDENTE                  object
# ESTADO METEREOLÓGICO            object
# TIPO VEHÍCULO                   object
# TIPO PERSONA                    object
# RANGO DE EDAD                   object
# SEXO                            object
# LESIVIDAD*                     float64
# Unnamed: 13                    float64
# Unnamed: 14                     object
# dtype: object

# %%
#No tocar, es para que veas la solución
# Out:
# FECHA                   datetime64[ns]
# HORA                            object
# CALLE                           object
# NÚMERO                          object
# DISTRITO                        object
# TIPO ACCIDENTE                  object
# ESTADO METEREOLÓGICO            object
# TIPO VEHÍCULO                   object
# TIPO PERSONA                    object
# RANGO DE EDAD                   object
# SEXO                            object
# LESIVIDAD*                     float64
# Unnamed: 13                    float64
# Unnamed: 14                     object
# dtype: object

# %% [markdown]
# ## Ejercicio:
#
# Como la mayoría son objetos haz una visión global de estadísticos que incluya solo las tipo objeto

# %%
df.describe(include= 'O').T
# Out:
#                       count unique                      top   freq
# HORA                  28773    976                 15:30:00    288
# CALLE                 28773   6988        PASEO. CASTELLANA    336
# NÚMERO                28771    470                        -  15323
# DISTRITO              28771     21       PUENTE DE VALLECAS   2358
# TIPO ACCIDENTE        28740     13  Colisión fronto-lateral   7044
# ESTADO METEREOLÓGICO  25964      7                Despejado  22092
# TIPO VEHÍCULO         28633     34                  Turismo  19490
# TIPO PERSONA          28746      3                Conductor  23519
# RANGO DE EDAD         28773     18              DESCONOCIDA   3513
# SEXO                  25398      2                   Hombre  17444
# Unnamed: 14               1      1                        ,      1

# %%
#No tocar, es para que veas la solución
# Out:
#                       count unique                      top   freq
# HORA                  28773    976                 15:30:00    288
# CALLE                 28773   6988        PASEO. CASTELLANA    336
# NÚMERO                28771    470                        -  15323
# DISTRITO              28771     21       PUENTE DE VALLECAS   2358
# TIPO ACCIDENTE        28740     13  Colisión fronto-lateral   7044
# ESTADO METEREOLÓGICO  25964      7                Despejado  22092
# TIPO VEHÍCULO         28633     34                  Turismo  19490
# TIPO PERSONA          28746      3                Conductor  23519
# RANGO DE EDAD         28773     18              DESCONOCIDA   3513
# SEXO                  25398      2                   Hombre  17444
# Unnamed: 14               1      1                        ,      1

# %% [markdown]
# ## Ejercicio:
#
# Comprueba si hay algún duplicado en el dataset

# %%
df.duplicated().sum()
# Out:
# np.int64(1313)

# %%
#No tocar, es para que veas la solución
# Out:
# 1313

# %% [markdown]
# ## Ejercicio:
#
# Muestra los duplicados sacando todas las repeteciones de cada uno.

# %%
df[df.duplicated(keep = False)]
# Out:
#                     FECHA      HORA  \
# Nº  EXPEDIENTE
# 2020S000061    2020-01-01  15:50:00
# 2020S000061    2020-01-01  15:50:00
# 2020S000061    2020-01-01  15:50:00
# 2020S000229    2020-01-01  15:00:00
# 2020S000229    2020-01-01  15:00:00
# ...                   ...       ...
# 2020S017273    2020-11-29  00:25:00
# 2020S017670    2020-11-30  22:35:00
# 2020S017670    2020-11-30  22:35:00
# 2020S017670    2020-11-30  22:35:00
# 2020S017670    2020-11-30  22:35:00
#
#                                                            CALLE NÚMERO  \
# Nº  EXPEDIENTE
# 2020S000061                              AVDA. VIRGEN DEL CARMEN      1
# 2020S000061                              AVDA. VIRGEN DEL CARMEN      1
# 2020S000061                              AVDA. VIRGEN DEL CARMEN      1
# 2020S000229                                        CALL. ARGÜESO     31
# 2020S000229                                        CALL. ARGÜESO     31
# ...

# %%
#No tocar, es para que veas la solución
# Out:
#                     FECHA      HORA  \
# Nº  EXPEDIENTE
# 2020S000061    2020-01-01  15:50:00
# 2020S000061    2020-01-01  15:50:00
# 2020S000061    2020-01-01  15:50:00
# ...                   ...       ...
# 2020S017670    2020-11-30  22:35:00
# 2020S017670    2020-11-30  22:35:00
# 2020S017670    2020-11-30  22:35:00
#
#                                                            CALLE NÚMERO  \
# Nº  EXPEDIENTE
# 2020S000061                              AVDA. VIRGEN DEL CARMEN      1
# 2020S000061                              AVDA. VIRGEN DEL CARMEN      1
# 2020S000061                              AVDA. VIRGEN DEL CARMEN      1
# ...                                                          ...    ...
# 2020S017670     CALL. TORRECILLA DEL PUERTO / CALL. ARTURO SORIA      -
# 2020S017670     CALL. TORRECILLA DEL PUERTO / CALL. ARTURO SORIA      -
# 2020S017670     CALL. TORRECILLA DEL PUERTO / CALL. ARTURO SORIA      -
#
# ...

# %% [markdown]
# ## Ejercicio:
#
# Calcula, dentro de los duplicados, cuantas veces está duplicado cada expediente.

# %%
df[df.duplicated(keep = False)].index.value_counts()
# Out:
# Nº  EXPEDIENTE
# 2020S007629    18
# 2020S007552    14
# 2020S005796    10
# 2020S001429     7
# 2020S012572     7
#                ..
# 2020S000070     2
# 2020S000074     2
# 2020S015365     1
# 2020S015426     1
# 2020S014760     1
# Name: count, Length: 941, dtype: int64

# %%
#No tocar, es para que veas la solución
# Out:
# 2020S007629    18
# 2020S007552    14
# 2020S005796    10
#                ..
# 2020S014760     1
# 2020S015426     1
# 2020S015365     1
# Name: Nº  EXPEDIENTE, Length: 941, dtype: int64

# %% [markdown]
# ## Ejercicio:
#
# ¿Cual es la calle en la que ha habido más accidentes?

# %%
df.CALLE.mode()
# Out:
# 0    PASEO. CASTELLANA
# Name: CALLE, dtype: object

# %%
#No tocar, es para que veas la solución
# Out:
# 0    PASEO. CASTELLANA
# dtype: object

# %% [markdown]
# ## Ejercicio:
#
# Hay una variable 'Unnamed: 14', que la reconoce como objeto y nos decía que solo tiene un valor. Explorar sus frecuencias

# %%
df['Unnamed: 14'].value_counts()
# Out:
# Unnamed: 14
# ,    1
# Name: count, dtype: int64

# %%
#No tocar, es para que veas la solución
# Out:
# ,    1
# Name: Unnamed: 14, dtype: int64

# %% [markdown]
# ## Ejercicio:
#
# Haz un análisis de nulos a ver cuantos tenemos por variable.

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Unnamed: 13             28773
# Unnamed: 14             28772
# LESIVIDAD*              13055
# SEXO                     3375
# ESTADO METEREOLÓGICO     2809
# TIPO VEHÍCULO             140
# TIPO ACCIDENTE             33
# TIPO PERSONA               27
# NÚMERO                      2
# DISTRITO                    2
# CALLE                       0
# HORA                        0
# FECHA                       0
# RANGO DE EDAD               0
# dtype: int64

# %%
#No tocar, es para que veas la solución
# Out:
# Unnamed: 13             28773
# Unnamed: 14             28772
# LESIVIDAD*              13055
# SEXO                     3375
# ESTADO METEREOLÓGICO     2809
# TIPO VEHÍCULO             140
# TIPO ACCIDENTE             33
# TIPO PERSONA               27
# NÚMERO                      2
# DISTRITO                    2
# FECHA                       0
# HORA                        0
# CALLE                       0
# RANGO DE EDAD               0
# dtype: int64

# %% [markdown]
# ## Ejercicio:
#
# Calcula el máximo, minimo, media y mediana de LESIVIDAD*

# %%
print('Máximo',df['LESIVIDAD*'].max())
print('Mínimo',df['LESIVIDAD*'].min())
print('Media',df['LESIVIDAD*'].mean())
print('Mediana',df['LESIVIDAD*'].median())
# Out:
# Máximo 77.0
# Mínimo 1.0
# Media 9.835856979259448
# Mediana 14.0

# %%
#No tocar, es para que veas la solución
# Out:
# Maximo:  77.0
# Mínimo:  1.0
# Media:  9.835856979259448
# Mediana:  14.0

# %% [markdown]
# BUEN TRABAJO!!!
